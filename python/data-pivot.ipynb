# %%
import pandas as pd

df = pd.read_csv("data.csv", encoding = "ISO-8859-1", engine='python')
df.head()
# Out:
#   CMS Certification Number (CCN)             Facility Name  \
# 0                         015009  BURNS NURSING HOME, INC.
# 1                         015009  BURNS NURSING HOME, INC.
# 2                         015009  BURNS NURSING HOME, INC.
# 3                         015009  BURNS NURSING HOME, INC.
# 4                         015009  BURNS NURSING HOME, INC.
#
#          Address Line 1          City State  Zip Code County Name  \
# 0  701 MONROE STREET NW  RUSSELLVILLE    AL     35653    Franklin
# 1  701 MONROE STREET NW  RUSSELLVILLE    AL     35653    Franklin
# 2  701 MONROE STREET NW  RUSSELLVILLE    AL     35653    Franklin
# 3  701 MONROE STREET NW  RUSSELLVILLE    AL     35653    Franklin
# 4  701 MONROE STREET NW  RUSSELLVILLE    AL     35653    Franklin
#
#     Phone Number  CMS Region               Measure Code  \
# 0  (256)332-4110           4       S_001_03_DENOMINATOR
# 1  (256)332-4110           4         S_001_03_NUMERATOR
# ...

# %%
result = df.pivot(columns='Measure Code', index = 'CMS Certification Number (CCN)', values = 'Score')
result.head()
# Out:
# Measure Code                   S_001_03_DENOMINATOR S_001_03_NUMERATOR  \
# CMS Certification Number (CCN)
# 015009                                          103                103
# 015010                                          180                173
# 015012                                          170                170
# 015014                                           59                 59
# 015015                                           60                 59
#
# Measure Code                   S_001_03_OBS_RATE  \
# CMS Certification Number (CCN)
# 015009                                     100.0
# 015010                                      96.1
# 015012                                     100.0
# 015014                                     100.0
# 015015                                      98.3
#
# Measure Code                              S_004_01_PPR_PD_COMP_PERF  \
# CMS Certification Number (CCN)
# 015009                          No Different than the National Rate
# ...

# %%
result.to_csv("for-correlation.csv")

# %%
#References - https://pandas.pydata.org/docs/user_guide/reshaping.html
